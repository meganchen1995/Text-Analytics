# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import re
import time

# %%
products = [
    ('Beats-Solo3-Wireless-Ear-Headphones', 'B01M0J9OD3'),
    ('Sony-Cancelling-Bluetooth-Headphone-MDR1000X', 'B01KHZ4ZYY'),
    ('beyerdynamic-770-closed-Studio-Headphone', 'B0016MNAAI'),
    ('Sennheiser-Open-Back-Professional-Headphone', 'B00004SY4H'),
    ('Bose-QuietComfort-Acoustic-Cancelling-Headphones', 'B00M1NEUKK'),
    ('Harman-Kardon-CL-Precision-Headphones', 'B00A3RVNXI'),
    ('Samsung-Level-Over-Ear-Bluetooth-Headphone', 'B00KGGK71A'),
    ('V-MODA-Crossfade-Over-Ear-Noise-Isolating-Headphone','B00A39PPI0')
]

# %%
amazon_product = pd.DataFrame(products, columns = ['productname','productid'])

# %%
amazon_product.to_csv('amazon_product.csv', index = None, encoding='utf-8')

# %%
def get_lastpage(url):
    page = requests.get(url)
    return int(re.findall('pageNumber=[0-9]+',page.content)[-2].replace('pageNumber=',''))

def get_reviews(url):
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    
    user_raw = soup.find_all('a', class_ = 'a-size-base a-link-normal author')
    time_raw = soup.find_all('span', class_ = 'a-size-base a-color-secondary review-date')
    rating_raw = soup.find_all('span', class_ = 'a-icon-alt')
    review_raw = soup.find_all('span', class_ = 'a-size-base review-text')
    
    
    userids = [u.text.strip() for u in user_raw]
    times = [t.text.strip()[3:] for t in time_raw][2:] #start from 4th letter to get rid of "on", get rid of first non-review time
    ratings = [float(r[:3]) for r in [r.text.strip() for r in rating_raw] if r != '|'][3:-5] #get rid of non-review ratings (e.g. overall product rating and similar product rating on the same page)
    reviews = [r.text.strip() for r in review_raw]
    
    return zip(userids,times,ratings,reviews)

# %%
amazon_review = pd.DataFrame()

for (p,i) in products:
    base_url = 'https://www.amazon.com/' + p + '/product-reviews/' + i + '/ref=cm_cr_arp_d_paging_btm_1?ie=UTF8&reviewerType=all_reviews&pageNumber='
    tot_page = get_lastpage(base_url + '1') #get total page number from first page
    urls = [base_url + '{}'.format(x) for x in range(1,tot_page + 1)] #get list of urls for all review pages
    reviews = []
    for url in urls:
        r = get_reviews(url)
        reviews += r
    df = pd.DataFrame(reviews, columns = ['userid','time','rating','review'])
    df['time'] = pd.to_datetime(df['time']).map(lambda x: x.date())
    df['productname'] = p
    df['productid'] = i
    amazon_review = amazon_review.append(df, ignore_index = True)

# %%
amazon_review.to_csv('amazon_review.csv', index = None, encoding='utf-8')

# %%
amazon_review
# Out:
#                                  userid        time  rating  \
# 0                            Kevin V Sr  2016-10-21     4.0
# 1                            MindSeedTV  2016-10-10     4.0
# 2                             Big Dutch  2016-10-21     5.0
# 3                         c0deName_ZERO  2016-11-28     4.0
# 4                       Amazon Customer  2016-12-27     5.0
# 5                                   Dan  2017-03-16     1.0
# 6                           KIMBERLY N.  2016-12-30     5.0
# 7                         Shepherd luvr  2017-10-01     5.0
# 8                                Jeremy  2017-04-06     4.0
# 9                       Mckaela Schmidt  2017-05-03     5.0
# 10                       Todd M. Kelman  2017-06-11     5.0
# 11              Yasmine Elizabeth Bacon  2017-01-26     1.0
# 12                         Raymond Hood  2017-04-25     4.0
# 13                        Ella Thompson  2017-05-22     4.0
# 14                                Kimmy  2017-01-17     4.0
# 15                               SarahB  2017-05-12     2.0
# 16                      Amazon Customer  2017-04-07     5.0
# 17                                   AS  2017-03-10     5.0
# 18                                   KJ  2017-08-06     4.0
# 19                       Fruit Basket#1  2017-08-28     2.0
# 20                                Aziza  2017-09-28     5.0
# 21                      Amazon Customer  2017-05-05     4.0
# 22                      Amazon Customer  2017-07-08     5.0
# 23                      Amazon Customer  2017-04-26     5.0
# 24                             Texasgal  2017-06-09     5.0
# 25                         Montana girl  2017-04-25     5.0
# 26                     Russell fotovich  2017-05-30     5.0
# 27                         Shoe Shopper  2017-09-27     5.0
# 28                         Manish Kumar  2016-12-08     5.0
# 29                              JohnnyS  2017-07-25     5.0
# ...                                 ...         ...     ...
# 8913                               will  2016-03-17     5.0
# 8914                             Henry!  2013-05-12     5.0
# 8915                                Jon  2013-02-13     5.0
# 8916                               ryan  2013-12-29     5.0
# 8917                        Duke Nguyen  2016-08-14     5.0
# 8918                                Tom  2014-08-31     5.0
# 8919                     LOVETHEBEACH21  2015-01-15     5.0
# 8920                     Adonis Doxilly  2016-01-24     5.0
# 8921                    Gloria De Volpe  2015-10-28     5.0
# 8922                Haithem M. Abdelaty  2014-06-16     3.0
# 8923                                 RJ  2014-07-04     4.0
# 8924                            Jake U.  2014-11-11     3.0
# 8925                            Dean H.  2015-01-02     4.0
# 8926                    Amazon Customer  2016-07-20     5.0
# 8927                             Daniel  2016-03-17     5.0
# 8928                        Paul Deakin  2017-05-17     2.0
# 8929                              Losch  2016-03-13     5.0
# 8930                          MisterCee  2013-10-13     5.0
# 8931                            Caohu09  2014-05-03     5.0
# 8932                         David Lane  2015-09-21     4.0
# 8933                              colin  2016-05-24     1.0
# 8934                    Amazon Customer  2013-01-20     2.0
# 8935                            Anthony  2014-12-23     1.0
# 8936                          Andrew N.  2014-11-29     5.0
# 8937                     Eric Antonelli  2015-01-13     1.0
# 8938  David  - Customer Service Manager  2016-09-03     1.0
# 8939                            ajg1874  2014-06-23     1.0
# 8940                     Kyle Kenworthy  2013-06-27     1.0
# 8941  David  - Customer Service Manager  2014-07-10     1.0
# 8942                           M. Afzal  2015-04-07     1.0
#
#                                                  review  \
# 0     Heads-up - this is a lengthy review - but when...
# 1     Great pair of Headphones!  I really love the q...
# 2     Disclaimer: I've never owned a pair of headpho...
# 3     Ladies & Gents this Review is best suited for ...
# 4     Crazy fast charging, wireless, comfortable on ...
# 5     Buyer Beware!!!  Thrilled with the price, I pu...
# 6     LOVE LOVE LOVE!! These are my first pair and t...
# 7     After looking at numerous headphones my wife s...
# 8     huge bass enhancement ( you can definitely tel...
# 9     I bought these for my boyfriend as a surprise ...
# 10    comfortable fit,  delivered quickly  excellent...
# 11    Very pricey. Felt like I sold my soul a little...
# 12    Very pleased. I have some less expensive, wire...
# 13    These headphones are absolutely worth the pric...
# 14    I purchased these earphones for a friend and w...
# 15    The sound quality is ok. These beats are terri...
# 16    After spending money here and there on headpho...
# 17    My search for the right wireless headsets ende...
# 18    These really good. I love how easily they conn...
# 19    The product I received is defective. The "b" b...
# 20    Amazing product! Love the wireless function. T...
# 21    I love the sound of these headphones, however ...
# 22    Great battery life and amazing bluetooth dista...
# 23    Exactly what I was looking for in a wireless o...
# 24    The only thing bad is it said it was prime but...
# 25    Gift for the grand daughter and she uses it at...
# 26    Outstanding sound, fit and battery. The contro...
# 27    Very happy with these. The battery charge last...
# 28    Best bluetooth headphone. Period. Quality is g...
# 29    Before I had this model of beats, I had the Mi...
# ...                                                 ...
# 8913  Amazing sound, by far the best headphones ive ...
# 8914  The reviews are true.  These headphones are gr...
# 8915  These sound great for bass heads and even more...
# 8916  Definitely the best pair of head phones I have...
# 8917  One of the best pair of headphones I've ever p...
# 8918            great Design & Sound quality, love it:)
# 8919  I own many different brands of headphones but ...
# 8920  V-moda user for 5 years. Okay this is how I wo...
# 8921  Sounds fantastic great design  !! I Will recom...
# 8922  I wish there were different rating criteria to...
# 8923  Original 1 Star Review:I bought the M100's two...
# 8924     Great pair of headphones, 40% worth the price.
# 8925  i love the sound quality but im more of a bass...
# 8926  I purchased these headphones as my first actua...
# 8927                                    Simply amazing.
# 8928  Sure they sound great until the screws on the ...
# 8929                                        Great sound
# 8930  Never before have I absolutely LOVED a pair of...
# 8931  I was looking at how cool these headphones wer...
# 8932  Close but not comfort built....I didn't get th...
# 8933  These headphones destroyed my life!!!!! The so...
# 8934  Nothing stood out in the phone for me. Nice pa...
# 8935  I bought these a couple years ago, and they ar...
# 8936  These headphones are the best! They are so por...
# 8937  My M100 arrived today, i unboxed them very hap...
# 8938  These are really not very good, not sure why t...
# 8939  I had been wanting a really great pair of head...
# 8940  NOT noise isolating.I was so very and deeply d...
# 8941  Bought from uk and the headband creeks ,will n...
# 8942  IT person must of went to PITT or something, b...
#
#                                             productname   productid
# 0                   Beats-Solo3-Wireless-Ear-Headphones  B01M0J9OD3
# 1                   Beats-Solo3-Wireless-Ear-Headphones  B01M0J9OD3
# 2                   Beats-Solo3-Wireless-Ear-Headphones  B01M0J9OD3
# 3                   Beats-Solo3-Wireless-Ear-Headphones  B01M0J9OD3
# 4                   Beats-Solo3-Wireless-Ear-Headphones  B01M0J9OD3
# 5                   Beats-Solo3-Wireless-Ear-Headphones  B01M0J9OD3
# 6                   Beats-Solo3-Wireless-Ear-Headphones  B01M0J9OD3
# 7                   Beats-Solo3-Wireless-Ear-Headphones  B01M0J9OD3
# 8                   Beats-Solo3-Wireless-Ear-Headphones  B01M0J9OD3
# 9                   Beats-Solo3-Wireless-Ear-Headphones  B01M0J9OD3
# 10                  Beats-Solo3-Wireless-Ear-Headphones  B01M0J9OD3
# 11                  Beats-Solo3-Wireless-Ear-Headphones  B01M0J9OD3
# 12                  Beats-Solo3-Wireless-Ear-Headphones  B01M0J9OD3
# 13                  Beats-Solo3-Wireless-Ear-Headphones  B01M0J9OD3
# 14                  Beats-Solo3-Wireless-Ear-Headphones  B01M0J9OD3
# 15                  Beats-Solo3-Wireless-Ear-Headphones  B01M0J9OD3
# 16                  Beats-Solo3-Wireless-Ear-Headphones  B01M0J9OD3
# 17                  Beats-Solo3-Wireless-Ear-Headphones  B01M0J9OD3
# 18                  Beats-Solo3-Wireless-Ear-Headphones  B01M0J9OD3
# 19                  Beats-Solo3-Wireless-Ear-Headphones  B01M0J9OD3
# 20                  Beats-Solo3-Wireless-Ear-Headphones  B01M0J9OD3
# 21                  Beats-Solo3-Wireless-Ear-Headphones  B01M0J9OD3
# 22                  Beats-Solo3-Wireless-Ear-Headphones  B01M0J9OD3
# 23                  Beats-Solo3-Wireless-Ear-Headphones  B01M0J9OD3
# 24                  Beats-Solo3-Wireless-Ear-Headphones  B01M0J9OD3
# 25                  Beats-Solo3-Wireless-Ear-Headphones  B01M0J9OD3
# 26                  Beats-Solo3-Wireless-Ear-Headphones  B01M0J9OD3
# 27                  Beats-Solo3-Wireless-Ear-Headphones  B01M0J9OD3
# 28                  Beats-Solo3-Wireless-Ear-Headphones  B01M0J9OD3
# 29                  Beats-Solo3-Wireless-Ear-Headphones  B01M0J9OD3
# ...                                                 ...         ...
# 8913  V-MODA-Crossfade-Over-Ear-Noise-Isolating-Head...  B00A39PPI0
# 8914  V-MODA-Crossfade-Over-Ear-Noise-Isolating-Head...  B00A39PPI0
# 8915  V-MODA-Crossfade-Over-Ear-Noise-Isolating-Head...  B00A39PPI0
# 8916  V-MODA-Crossfade-Over-Ear-Noise-Isolating-Head...  B00A39PPI0
# 8917  V-MODA-Crossfade-Over-Ear-Noise-Isolating-Head...  B00A39PPI0
# 8918  V-MODA-Crossfade-Over-Ear-Noise-Isolating-Head...  B00A39PPI0
# 8919  V-MODA-Crossfade-Over-Ear-Noise-Isolating-Head...  B00A39PPI0
# 8920  V-MODA-Crossfade-Over-Ear-Noise-Isolating-Head...  B00A39PPI0
# 8921  V-MODA-Crossfade-Over-Ear-Noise-Isolating-Head...  B00A39PPI0
# 8922  V-MODA-Crossfade-Over-Ear-Noise-Isolating-Head...  B00A39PPI0
# 8923  V-MODA-Crossfade-Over-Ear-Noise-Isolating-Head...  B00A39PPI0
# 8924  V-MODA-Crossfade-Over-Ear-Noise-Isolating-Head...  B00A39PPI0
# 8925  V-MODA-Crossfade-Over-Ear-Noise-Isolating-Head...  B00A39PPI0
# 8926  V-MODA-Crossfade-Over-Ear-Noise-Isolating-Head...  B00A39PPI0
# 8927  V-MODA-Crossfade-Over-Ear-Noise-Isolating-Head...  B00A39PPI0
# 8928  V-MODA-Crossfade-Over-Ear-Noise-Isolating-Head...  B00A39PPI0
# 8929  V-MODA-Crossfade-Over-Ear-Noise-Isolating-Head...  B00A39PPI0
# 8930  V-MODA-Crossfade-Over-Ear-Noise-Isolating-Head...  B00A39PPI0
# 8931  V-MODA-Crossfade-Over-Ear-Noise-Isolating-Head...  B00A39PPI0
# 8932  V-MODA-Crossfade-Over-Ear-Noise-Isolating-Head...  B00A39PPI0
# 8933  V-MODA-Crossfade-Over-Ear-Noise-Isolating-Head...  B00A39PPI0
# 8934  V-MODA-Crossfade-Over-Ear-Noise-Isolating-Head...  B00A39PPI0
# 8935  V-MODA-Crossfade-Over-Ear-Noise-Isolating-Head...  B00A39PPI0
# 8936  V-MODA-Crossfade-Over-Ear-Noise-Isolating-Head...  B00A39PPI0
# 8937  V-MODA-Crossfade-Over-Ear-Noise-Isolating-Head...  B00A39PPI0
# 8938  V-MODA-Crossfade-Over-Ear-Noise-Isolating-Head...  B00A39PPI0
# 8939  V-MODA-Crossfade-Over-Ear-Noise-Isolating-Head...  B00A39PPI0
# 8940  V-MODA-Crossfade-Over-Ear-Noise-Isolating-Head...  B00A39PPI0
# 8941  V-MODA-Crossfade-Over-Ear-Noise-Isolating-Head...  B00A39PPI0
# 8942  V-MODA-Crossfade-Over-Ear-Noise-Isolating-Head...  B00A39PPI0
#
# [8943 rows x 6 columns]
